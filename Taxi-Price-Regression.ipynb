# %%
import pandas as pd 
df = pd.read_csv("taxi_trip_pricing.csv")

# %%
df.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# 3                 116.81     36.4698
# 4                  22.64     15.6180

# %%
df.isnull().sum()
# Out:
# Trip_Distance_km         50
# Time_of_Day              50
# Day_of_Week              50
# Passenger_Count          50
# Traffic_Conditions       50
# Weather                  50
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price               49
# dtype: int64

# %%
df.tail(60)
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 940             14.43     Morning     Weekday              4.0
# 941             28.15   Afternoon     Weekday              2.0
# 942             32.92     Evening     Weekday              4.0
# 943               NaN     Evening     Weekend              1.0
# 944             11.11     Evening     Weekend              3.0
# 945              1.54   Afternoon     Weekday              3.0
# 946              7.71   Afternoon     Weekday              3.0
# 947             45.10     Morning     Weekday              3.0
# 948             43.82   Afternoon     Weekday              4.0
# 949             30.27   Afternoon     Weekend              4.0
# 950             30.43     Morning     Weekend              2.0
# 951             33.59     Morning     Weekday              4.0
# 952              9.59   Afternoon     Weekend              2.0
# 953             45.81     Evening     Weekday              2.0
# 954             21.52       Night     Weekend              3.0
# 955             19.77       Night     Weekday              4.0
# 956             26.43   Afternoon     Weekend              4.0
# 957              3.30   Afternoon     Weekend              2.0
# 958              9.15   Afternoon     Weekday              2.0
# 959             37.16     Evening     Weekend              1.0
# 960              5.06     Morning     Weekday              1.0
# 961               NaN   Afternoon     Weekday              2.0
# 962             13.02     Evening     Weekday              1.0
# 963             20.08   Afternoon     Weekend              1.0
# 964             15.15   Afternoon     Weekend              2.0
# 965             18.43   Afternoon     Weekend              2.0
# 966             36.23     Morning     Weekend              4.0
# 967             15.56   Afternoon     Weekday              2.0
# 968             28.75   Afternoon     Weekend              2.0
# 969             24.33     Morning     Weekday              3.0
# 970               NaN     Morning     Weekday              4.0
# 971             46.90     Evening     Weekday              4.0
# 972             36.90     Morning     Weekend              4.0
# 973             11.53   Afternoon     Weekend              3.0
# 974              2.53     Morning     Weekday              2.0
# 975             13.85       Night     Weekday              4.0
# 976             30.16     Morning     Weekend              4.0
# 977              3.52   Afternoon     Weekday              NaN
# 978             25.32     Evening     Weekend              4.0
# 979             30.25     Evening     Weekend              2.0
# 980             17.38     Morning     Weekday              2.0
# 981             38.77     Evening     Weekday              1.0
# 982              6.22   Afternoon     Weekend              4.0
# 983              4.68   Afternoon     Weekend              4.0
# 984             36.68     Morning     Weekday              4.0
# 985             25.28     Morning     Weekend              3.0
# 986             34.73     Evening     Weekday              4.0
# 987             22.31   Afternoon     Weekday              2.0
# 988             13.07         NaN     Weekend              2.0
# 989             41.14     Evening     Weekend              3.0
# 990             40.17     Evening     Weekday              3.0
# 991             35.04     Morning     Weekend              4.0
# 992             14.34   Afternoon     Weekday              1.0
# 993               NaN     Morning     Weekday              3.0
# 994             18.69     Evening     Weekday              3.0
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 940               High   Clear       2.81         1.46             0.21
# 941               High   Clear       2.06         0.61             0.18
# 942                Low   Clear       4.17         0.70             0.36
# 943                Low    Snow       2.10         1.47             0.27
# 944             Medium   Clear       3.79         1.01             0.17
# 945               High   Clear       3.62         1.56             0.38
# 946                Low   Clear       4.91          NaN             0.33
# 947             Medium   Clear        NaN         0.88             0.44
# 948                Low   Clear       2.19         1.48             0.15
# 949             Medium   Clear       3.66         0.67             0.41
# 950             Medium   Clear       4.52         1.30             0.37
# 951             Medium   Clear       4.99         1.16             0.15
# 952               High   Clear       3.29         0.90             0.38
# 953               High   Clear        NaN         1.41             0.28
# 954               High    Rain       4.72         1.81             0.48
# 955                Low   Clear       2.57         2.00             0.16
# 956             Medium   Clear       3.85         1.41             0.36
# 957                Low   Clear       3.22         1.11             0.25
# 958             Medium    Snow       2.12         0.84             0.48
# 959             Medium    Snow       3.04         0.89             0.23
# 960             Medium     NaN       2.80         1.22             0.48
# 961             Medium   Clear       4.06         1.05             0.46
# 962               High   Clear       4.85         1.87              NaN
# 963                Low   Clear       2.80         1.05             0.42
# 964                NaN   Clear       4.43         1.06             0.50
# 965                Low   Clear       2.17         1.08             0.20
# 966                NaN    Rain       3.61          NaN             0.27
# 967                NaN    Rain       2.21         1.48              NaN
# 968               High    Rain       4.80         1.42             0.22
# 969               High   Clear       4.30         1.00             0.11
# 970               High   Clear       3.97         1.73             0.19
# 971               High   Clear       4.47         0.56             0.21
# 972                Low   Clear       3.94         1.81             0.28
# 973                Low    Rain       4.91         1.27             0.17
# 974             Medium   Clear       4.14         1.10             0.45
# 975             Medium   Clear       4.77         1.25             0.38
# 976             Medium   Clear       3.55         1.50             0.13
# 977                Low   Clear       2.35          NaN             0.36
# 978             Medium    Rain       3.58         1.81             0.36
# 979             Medium   Clear       2.38         1.17             0.48
# 980                Low    Rain       3.78         1.01             0.10
# 981             Medium   Clear       3.45         0.71             0.20
# 982             Medium   Clear       3.87         1.16             0.47
# 983             Medium    Rain       2.03         1.24             0.47
# 984                Low   Clear       2.58         1.11             0.39
# 985             Medium    Snow       3.47         1.52              NaN
# 986                Low   Clear       4.85         1.13             0.14
# 987                Low   Clear       3.15         1.94             0.31
# 988             Medium   Clear       3.27         1.40             0.19
# 989             Medium    Rain       4.14         1.71             0.17
# 990                Low   Clear       3.81         0.66             0.42
# 991             Medium    Rain       2.90         1.10             0.15
# 992             Medium   Clear       3.23         1.01             0.29
# 993             Medium   Clear       2.65         1.35              NaN
# 994             Medium   Clear       4.90         1.79             0.17
# 995             Medium   Clear       2.39         0.62             0.49
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
# 998                Low   Clear       2.67         0.82             0.17
# 999             Medium   Clear       4.34          NaN             0.23
#
#      Trip_Duration_Minutes  Trip_Price
# 940                  24.69     29.0627
# 941                  17.02     22.2951
# 942                  32.31     38.8456
# 943                  48.69     76.4865
# 944                  59.73     25.1652
# 945                  10.13      9.8718
# 946                 116.62     53.7260
# 947                  87.35     81.5720
# 948                  42.17     73.3691
# 949                  41.65     41.0174
# 950                  56.58     65.0136
# 951                  77.02     55.5074
# 952                  21.83     20.2164
# 953                  26.73     75.0365
# 954                 103.83     93.5096
# 955                  34.47     47.6252
# 956                  48.72     58.6555
# 957                 105.20     33.1830
# 958                  81.26     48.8108
# 959                  44.30     46.3014
# 960                  83.63     49.1156
# 961                   7.26     39.4771
# 962                  89.60     48.0134
# 963                    NaN     49.5082
# 964                  98.52     69.7490
# 965                 114.78     45.0304
# 966                    NaN     97.1094
# 967                 109.57     59.2055
# 968                  63.90     59.6830
# 969                  46.42     33.7362
# 970                  58.48     73.0708
# 971                  84.34     48.4454
# 972                 106.66    100.5938
# 973                    NaN     24.4491
# 974                 110.59     56.6885
# 975                  98.75     59.6075
# 976                 117.57         NaN
# 977                 106.23     42.4232
# 978                  37.19     62.7976
# 979                  17.18     46.0189
# 980                  17.91     23.1248
# 981                  38.49     38.6747
# 982                  75.63     46.6313
# 983                  97.50     53.6582
# 984                 108.41     85.5747
# 985                  76.73     73.3549
# 986                   5.65     44.8859
# 987                  26.43     54.6247
# 988                  16.47     24.6973
# 989                  46.78     82.4420
# 990                  62.66     56.6394
# 991                   9.99         NaN
# 992                  45.07     30.7837
# 993                  25.61     55.3348
# 994                  79.41     51.8548
# 995                  58.39     34.4049
# 996                  61.96     62.1295
# 997                  54.18     33.1236
# 998                 114.94     61.2090
# 999                  29.69     45.4437

# %%
cat_cols = df.select_dtypes(include=['object']).columns

# %%
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])
# We fill missing categorical values using mode to handle NaN values safely.

# %%
# mode() can return multiple values if a column has more than one frequent category.
# iloc[0] selects the first mode to fill NaN values.

# %%
num_cols = df.select_dtypes(include=['float64','int64']).columns

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
# We fill missing numeric values using median to handle NaN values safely.

# %%
df.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# Trip_Price               0
# dtype: int64

# %%
df = pd.get_dummies(df,columns = ["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"],drop_first=True)
# Convert categorical columns into dummy variables (one-hot encoding) and drop the first category to avoid multicollinearity.

# %%
#target
y = df["Trip_Price"]

# %%
#features
X = df.drop(columns=["Trip_Price"])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
#StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha = 1.0)
lasso.fit(X_train_scaled,y_train)
# Out:
# Lasso()

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
#Measure performance
y_pred = lasso.predict(X_test_scaled)
r2 = r2_score(y_test,y_pred)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))

# %%
print("R2 SCORE : ",r2)
print("RMSE : ",rmse)
# Out:
# R2 SCORE :  0.7520380360431425
# RMSE :  18.237786717713178

# %%
# Create a DataFrame to inspect Lasso coefficients for each feature (feature importance and selection).
coeff_df = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": lasso.coef_
})

# %%
coeff_df
# Out:
#                       Feature  Coefficient
# 0            Trip_Distance_km    33.701047
# 1             Passenger_Count     0.000000
# 2                   Base_Fare     0.000000
# 3                 Per_Km_Rate     9.044208
# 4             Per_Minute_Rate     4.830681
# 5       Trip_Duration_Minutes     7.953705
# 6         Time_of_Day_Evening    -0.000000
# 7         Time_of_Day_Morning     0.000000
# 8           Time_of_Day_Night    -0.000000
# 9         Day_of_Week_Weekend    -0.000000
# 10     Traffic_Conditions_Low     0.000000
# 11  Traffic_Conditions_Medium    -0.000000
# 12               Weather_Rain    -0.000000
# 13               Weather_Snow     0.000000

# %%
#Model tuning to find the best alpha value

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score

alphas = [0.001, 0.01, 0.1, 1, 10, 50, 100, 1000, 10000]

for a in alphas:
    model = Lasso(alpha=a, max_iter=10000)
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring="r2").mean()
    print(a, "-" ,score)
# Out:
# 0.001 - 0.8342110538364385
# 0.01 - 0.8343287477464661
# 0.1 - 0.835328115181543
# 1 - 0.8362870296803564
# 10 - 0.6370887439854332
# 50 - -0.003562095751005412
# 100 - -0.003562095751005412
# 1000 - -0.003562095751005412
# 10000 - -0.003562095751005412

# %%
# The best alpha value is 1 because it achieved the highest mean cross-validation R² score

# %%
alpha_best = Lasso(alpha=1)
alpha_best.fit(X_train_scaled,y_train)
# Out:
# Lasso(alpha=1)

# %%
y_pred_best = alpha_best.predict(X_test_scaled)

# %%
print("final R2 : ",r2_score(y_test,y_pred_best))
print("final MSE : ",np.sqrt(mean_squared_error(y_test,y_pred_best)))
# Out:
# final R2 :  0.7520380360431425
# final MSE :  18.237786717713178
